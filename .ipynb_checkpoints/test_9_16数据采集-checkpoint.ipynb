# %% [markdown]
# 数据采集

# %%
import requests
import re

# %%
def geturls():
    url = "http://www.qstheory.cn/dukan/qs/2014/2019-01/01/c_1123924172.htm"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/140.0.0.0 Safari/537.36"
    }
    response = requests.get(url,headers=headers)
    result = response.content.decode("utf8")
    res = r'<a href="(.*?)" target="_blank">.*?<strong>(.*?)</strong>'
    urls_titles = re.findall(res, result, re.S)
    
    return urls_titles

# %%
urls_titles = geturls()

# %%
urls_titles
# Out:
# [('//www.qstheory.cn',
#   '<font style="COLOR: #993300; FONT-SIZE: 20pt"><font color="#993300"><font style="FONT-SIZE: 20pt"><font style="FONT-SIZE: 20pt" size="1"><font style="FONT-SIZE: 20pt">目 \xa0</font>录</font></font></font></font>'),
#  ('//www.qstheory.cn/dukan/qs/2019-01/01/c_1123924154.htm', '本期导读'),
#  ('//www.qstheory.cn/dukan/qs/2018-12/31/c_1123923896.htm',
#   '辩证唯物主义是中国共产党人的世界观和方法论'),
#  ('//www.qstheory.cn/dukan/qs/2019-01/01/c_1123923886.htm',
#   '学好用好马克思主义哲学这个看家本领'),
#  ('//www.qstheory.cn/dukan/qs/2019-01/01/c_1123923852.htm',
#   '增强脚力眼力脑力笔力 守正创新做好新形势下宣传思想工作'),
#  ('//www.qstheory.cn/dukan/qs/2019-01/01/c_1123923828.htm',
#   '以习近平外交思想为引领 不断开创中国特色大国外交新局面'),
#  ('//www.qstheory.cn/dukan/qs/2019-01/01/c_1123923817.htm',
#   '社论：砥砺奋进 开拓创新 以优异成绩迎接中华人民共和国成立70周年'),
#  ('//www.qstheory.cn/dukan/qs/2019-01/01/c_1123923778.htm', '论新时代'),
#  ('//www.qstheory.cn/dukan/qs/2019-01/01/c_1123923740.htm',
#   '重温《关于若干历史问题的决议》 坚定“两个维护”的自觉'),
# ...

# %%
def get_article_content(article_url):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/140.0.0.0 Safari/537.36"
    }

    response = requests.get(article_url, headers=headers)
    response.encoding = 'utf-8'
    html_content = response.text

    content_pattern1 = r'<div[^>]*class="text"[^>]*>(.*?)</div>'
    content_match = re.findall(content_pattern1, html_content, re.S)

# %%
content = get_article_content("http://www.qstheory.cn/dukan/qs/2018-12/31/c_1123923896.htm")

# %%
content
