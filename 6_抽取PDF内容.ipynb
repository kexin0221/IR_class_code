# %% [markdown]
# ## 抽取PDF内容

# %% [markdown]
# ##### 实验内容：https://www.jianshu.com/p/31939ee6f1c9

# %%
import glob
import os
from pdfminer.high_level import extract_text
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 3
#       1 import glob
#       2 import os
# ----> 3 from pdfminer.high_level import extract_text
#       4 import pandas as pd
#       5 import matplotlib.pyplot as plt
#
# File C:\ProgramData\anaconda3\envs\anaconda\Lib\site-packages\pdfminer\high_level.py:8
#       5 from io import StringIO
#       6 from typing import Any, BinaryIO, Container, Iterator, Optional, cast
# ----> 8 from .converter import (
#       9     XMLConverter,
#      10     HTMLConverter,
#      11     TextConverter,
#      12     PDFPageAggregator,
#      13     HOCRConverter,
#      14 )
#      15 from .image import ImageWriter
#      16 from .layout import LAParams, LTPage
#
# File C:\ProgramData\anaconda3\envs\anaconda\Lib\site-packages\pdfminer\converter.py:18
#       3 import re
#       4 from typing import (
#       5     BinaryIO,
#       6     Dict,
#    (...)     15     cast,
#      16 )
# ---> 18 from pdfminer.pdfcolor import PDFColorSpace
#      19 from . import utils
#      20 from .image import ImageWriter
#
# File C:\ProgramData\anaconda3\envs\anaconda\Lib\site-packages\pdfminer\pdfcolor.py:4
#       1 import collections
#       2 from typing import Dict
# ----> 4 from .psparser import LIT
#       6 LITERAL_DEVICE_GRAY = LIT("DeviceGray")
#       7 LITERAL_DEVICE_RGB = LIT("DeviceRGB")
#
# File C:\ProgramData\anaconda3\envs\anaconda\Lib\site-packages\pdfminer\psparser.py:22
#       7 from typing import (
#       8     Any,
#       9     BinaryIO,
#    (...)     18     Union,
#      19 )
#      21 from . import settings
# ---> 22 from .utils import choplist
#      24 log = logging.getLogger(__name__)
#      27 class PSException(Exception):
#
# File C:\ProgramData\anaconda3\envs\anaconda\Lib\site-packages\pdfminer\utils.py:31
#      28 if TYPE_CHECKING:
#      29     from .layout import LTComponent
# ---> 31 import charset_normalizer  # For str encoding detection
#      33 # from sys import maxint as INF doesn't work anymore under Python3, but PDF
#      34 # still uses 32 bits ints
#      35 INF = (1 << 31) - 1
#
# File C:\ProgramData\anaconda3\envs\anaconda\Lib\site-packages\charset_normalizer\__init__.py:24
#       2 """
#       3 Charset-Normalizer
#       4 ~~~~~~~~~~~~~~
#    (...)     20 :license: MIT, see LICENSE for more details.
#      21 """
#      22 import logging
# ---> 24 from .api import from_bytes, from_fp, from_path, normalize
#      25 from .legacy import (
#      26     CharsetDetector,
#      27     CharsetDoctor,
#    (...)     30     detect,
#      31 )
#      32 from .models import CharsetMatch, CharsetMatches
#
# File C:\ProgramData\anaconda3\envs\anaconda\Lib\site-packages\charset_normalizer\api.py:10
#       7 except ImportError:  # pragma: no cover
#       8     PathLike = str  # type: ignore
# ---> 10 from .cd import (
#      11     coherence_ratio,
#      12     encoding_languages,
#      13     mb_encoding_languages,
#      14     merge_coherence_ratios,
#      15 )
#      16 from .constant import IANA_SUPPORTED, TOO_BIG_SEQUENCE, TOO_SMALL_SEQUENCE, TRACE
#      17 from .md import mess_ratio
#
# File C:\ProgramData\anaconda3\envs\anaconda\Lib\site-packages\charset_normalizer\cd.py:9
#       7 from .assets import FREQUENCIES
#       8 from .constant import KO_NAMES, LANGUAGE_SUPPORTED_COUNT, TOO_SMALL_SEQUENCE, ZH_NAMES
# ----> 9 from .md import is_suspiciously_successive_range
#      10 from .models import CoherenceMatches
#      11 from .utils import (
#      12     is_accentuated,
#      13     is_latin,
#    (...)     16     unicode_range,
#      17 )
#
# File C:\ProgramData\anaconda3\envs\anaconda\Lib\site-packages\charset_normalizer\md.py:5
#       2 from typing import List, Optional
#       4 from .constant import COMMON_SAFE_ASCII_CHARACTERS, UNICODE_SECONDARY_RANGE_KEYWORD
# ----> 5 from .utils import (
#       6     is_accentuated,
#       7     is_ascii,
#       8     is_case_variable,
#       9     is_cjk,
#      10     is_emoticon,
#      11     is_hangul,
#      12     is_hiragana,
#      13     is_katakana,
#      14     is_latin,
#      15     is_punctuation,
#      16     is_separator,
#      17     is_symbol,
#      18     is_thai,
#      19     remove_accent,
#      20     unicode_range,
#      21 )
#      24 class MessDetectorPlugin:
#      25     """
#      26     Base abstract class used for mess detection plugins.
#      27     All detectors MUST extend and implement given methods.
#      28     """
#
# ImportError: cannot import name 'is_ascii' from 'charset_normalizer.utils' (C:\ProgramData\anaconda3\envs\anaconda\Lib\site-packages\charset_normalizer\utils.py)
